# %%
import seaborn as sns 
import pandas as pd

# %%
df=sns.load_dataset("mpg")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df=df.drop(["name","origin","model_year"],axis=1)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
# [398 rows x 6 columns]

# %%
df["horsepower"]=df['horsepower'].fillna(df["horsepower"].mean())

# %%
x=df.drop("mpg",axis=1) ### Features 
y=df["mpg"]### Target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=45)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_test_scaled=sc.fit_transform(x_test)
x_train_scaled=sc.fit_transform(x_train)

# %%
##### MLP ARC
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense### Each neuron will connect to each and every other neuron

# %%
model=Sequential()

# %%
### Layer 1(input layer)

# %%
model.add(Dense(units=10,activation="relu"))

# %%
### Hidden  Layer
model.add(Dense(units=10,activation="relu"))
model.add(Dense(units=10,activation="relu"))
model.add(Dense(units=10,activation="relu"))

# %%
##### OUTPUT LAYERS 
model.add(Dense(units=1,activation="relu"))

# %%
#### MODEL BUILDING
model.compile(optimizer="adam",loss="mse",metrics=["accuracy"])

# %%
model.fit(x_train_scaled,y_train,epochs=500,batch_size=32)
# Out:
# Epoch 1/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: 606.9993
# Epoch 2/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 603.8696
# Epoch 3/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 599.7523
# Epoch 4/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 593.9448
# Epoch 5/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 585.2267
# Epoch 6/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 571.2642
# Epoch 7/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 550.5825
# Epoch 8/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 519.6346
# Epoch 9/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 474.0654
# Epoch 10/500
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 405.8658
# Epoch 11/500
# ...

# %%
pred=model.predict(x_test_scaled)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
pred
# Out:
# array([[25.813843 ],
#        [33.079357 ],
#        [17.207432 ],
#        [31.596981 ],
#        [30.685114 ],
#        [12.274631 ],
#        [37.101967 ],
#        [16.481314 ],
#        [27.46951  ],
#        [14.779602 ],
#        [12.9744835],
#        [13.797355 ],
#        [27.100838 ],
#        [33.60477  ],
#        [12.327776 ],
#        [17.263302 ],
#        [13.402793 ],
#        [10.340199 ],
#        [22.706053 ],
#        [14.849539 ],
#        [33.74003  ],
#        [15.512411 ],
#        [30.239792 ],
#        [32.58723  ],
#        [30.34412  ],
#        [28.980959 ],
#        [26.218012 ],
#        [15.733184 ],
#        [20.84496  ],
#        [26.955345 ],
#        [21.227203 ],
#        [25.330883 ],
#        [12.844347 ],
#        [32.015945 ],
#        [25.47499  ],
#        [26.711414 ],
#        [14.992295 ],
#        [18.570942 ],
#        [33.116978 ],
#        [24.215813 ],
#        [25.378506 ],
#        [28.414532 ],
#        [22.802095 ],
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error

print(r2_score(y_test,pred)**0.5)
print(mean_squared_error(y_test,pred)**0.5)
# Out:
# 0.8107060253464231
# 4.2798062643057
